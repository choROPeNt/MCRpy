# %%
import os
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
import fnmatch
import nrrd

# %%
path = "data/FVC40_011_000_labels.npy"

# %%
micro = np.load(path)

micro_bin = np.array(micro[1:,1:] >0,dtype=np.int16)

# %%
plt.imshow(micro_bin[::,::]+1,cmap="plasma")

# %%
micro_bin_out = micro_bin[::2,::2]

# %%
np.save("FVC40_011_000_test_128x128.npy",micro_bin_out)

# %%
print(micro_bin_out.shape)
# Out:
# (128, 128)
